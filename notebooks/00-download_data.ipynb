# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel" : "mpg",
        "descricao" : "Medida utilizada para determinar a eficiência de combustível de um veículo",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },{
        "variavel" : "cylinders",
        "descricao" : "Quantidade de cilindros",
        "tipo" : "quantitativa",
        "subtipo" : "discreta"
    },{
        "variavel" : "displacement",
        "descricao" : "Se refere ao volume de gás sugado ou descarregado por curso do pistão",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },{
        "variavel" : "horsepower",
        "descricao" : "Representa a quantidade de trabalho que um motor pode realizar em um determinado intervalo de tempo",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },{
        "variavel" : "weight",
        "descricao" : "Peso do veículo",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },{
        "variavel" : "acceleration",
        "descricao" : "Mecanismo que permite ao motorista aumentar ou diminuir a velocidade do veículo",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },{
        "variavel" : "model_year",
        "descricao" : "Ano de fabricação",
        "tipo" : "quantitativa",
        "subtipo" : "discreta"
    },{
        "variavel" : "origin",
        "descricao" : "País de origem",
        "tipo" : "qualitativa",
        "subtipo" : "nominal"
    },{
        "variavel" : "name",
        "descricao" : "Nome do modelo",
        "tipo" : "qualitativa",
        "subtipo" : "nominal"
    }
])
dicionario
# Out:
#        variavel                                          descricao  \
# 0           mpg  Medida utilizada para determinar a eficiência ...
# 1     cylinders                            Quantidade de cilindros
# 2  displacement  Se refere ao volume de gás sugado ou descarreg...
# 3    horsepower  Representa a quantidade de trabalho que um mot...
# 4        weight                                    Peso do veículo
# 5  acceleration  Mecanismo que permite ao motorista aumentar ou...
# 6    model_year                                  Ano de fabricação
# 7        origin                                     País de origem
# 8          name                                     Nome do modelo
#
#            tipo   subtipo
# 0  quantitativa  contínua
# 1  quantitativa  discreta
# 2  quantitativa  contínua
# 3  quantitativa  contínua
# 4  quantitativa  contínua
# 5  quantitativa  contínua
# 6  quantitativa  discreta
# 7   qualitativa   nominal
# 8   qualitativa   nominal

# %%
dicionario.to_csv("../data/external/dictionary.csv", index=False)
